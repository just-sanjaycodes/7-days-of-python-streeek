# %%
fruits =['apple','mango','banaba','pineapple']
for fruit in fruits:
    print(fruit)
# Out:
# apple
# mango
# banaba
# pineapple

# %%
fruits =['apple','mango','banaba','pineapple']
fruits.insert(0,"Guava")
for fruit in fruits:
    print(fruit)
# Out:
# Guava
# apple
# mango
# banaba
# pineapple

# %%
# claear() method
fruits =["mango","banana","apple" ]
print(fruits.index("apple"))
print(fruits.count("banana")
)
# Out:
# 2
# 1

# %%
# sets lesson
veggies ={'carrot','tomato','coliflover','ladiesfinger'}
# print(dir(veggies))
# print((help(veggies)))
print(len(veggies))
print('carrot' in veggies)
veggies.add('cucumber')
veggies.remove('tomato')
veggies.pop()
veggies.clear()

for veg in veggies:
    print(veg)
# Out:
# 4
# True

# %%
# tuples
veggies =('carrot','tomato','coliflover','ladiesfinger')
print(len(veggies))
# print(dir(veggies))
print(veggies.index("carrot"))
veggies.count('carrot')

for veg in veggies:
    print(veg)
# Out:
# 4
# 0
# carrot
# tomato
# coliflover
# ladiesfinger

# %%
# 69. Remove duplicates from a list by converting it to a set and back to a list.
name =['1','2','3','1','2']
print(name)
print(name2:=set(name))
print(list(sorted.name2()))
# Out:
# ['1', '2', '3', '1', '2']
# {'3', '2', '1'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 5
#       1 # 69. Remove duplicates from a list by converting it to a set and back to a list.
#       2 name =['1','2','3','1','2']
#       3 print(name)
#       4 print(name2:=set(name))
# ----> 5 print(list(sorted.name2()))
#       6
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'name2'

# %%
num1 =[1,2,1,3,4,5,15,7,8,9]
print(num1)
print(num2:=set(num1))
print(list(num2))
for num in num2:
    print(num)
# Out:
# [1, 2, 1, 3, 4, 5, 15, 7, 8, 9]
# {1, 2, 3, 4, 5, 7, 8, 9, 15}
# [1, 2, 3, 4, 5, 7, 8, 9, 15]
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9
# 15

# %%
# 70. Check if an element exists in a set vs a list using in , and note (in a comment) why
# sets are faster for this.

values =[1,2,3,4,5]
value =125
if value in values:
    print(True)
else:
    print("false")
# Out:
# false

# %%
values =[1,2,6,4,5]
value =78
if value in values:
    print(value)

# %%
# # Section 8: Dictionaries (Q71–80)
# 71. Create a dictionary of 5 students with their marks and print it.

# Dictionary = a collectipn of {key:value} pairs mo duplicates



capital ={'india':'new delhi',
           'china':'beging',
           'russia':'moscow',
           "usa":'washigton dc'}

# print(dir(capital))
# print(capital.get("india"))

if capital.get("japan"):
    print(f"captial exists{capital}")
else:
    print("it doesnt exists")


capital.update({"Germany":"berlin"})
print(capital)

capital.pop('china')
capital.popitem()

# capital.clear()
print(keys :=capital.keys()) 


for key in capital.keys():
    print(key)


values =capital.values()
for value in capital.values():
    print(value)
# Out:
# it doesnt exists
# {'india': 'new delhi', 'china': 'beging', 'russia': 'moscow', 'usa': 'washigton dc', 'Germany': 'berlin'}
# dict_keys(['india', 'russia', 'usa'])
# india
# russia
# usa
# new delhi
# moscow
# washigton dc

# %%
capitals ={'india':'new delhi',
           'china':'beging',
           'russia':'moscow',
           "usa":'washigton dc'}

# print(dir(capital))

# items =capitals.items()
# print(items)


for key, value in capitals.items():
    print(f"{key}: {value}")
# Out:
# india: new delhi
# china: beging
# russia: moscow
# usa: washigton dc

# %%
# 71. Create a dictionary of 5 students with their marks and print it.

s_marks ={'anil':"85",
          "arun":'89',
          'aman':'45',
          'akshay':'25'
          }
print(s_marks)
s_marks.update({"akir":"456"})
# 72. Access a value by key, and safely access a missing key using .get() with a default
# value.

key =s_marks.get('anil')
print(key)
# Out:
# {'anil': '85', 'arun': '89', 'aman': '45', 'akshay': '25'}
# 85

# %%
# 73. Add a new key-value pair to a dictionary, then update an existing value.
s_marks ={'anil':"85",
          "arun":'89',
          'aman':'45',
          'akshay':'25'
          }

s_marks.update({'arindati':'97'})
print(s_marks)
# Out:
# {'anil': '85', 'arun': '89', 'aman': '45', 'akshay': '25', 'arindati': '97'}

# %%
# poping or deleting
s_marks ={'anil':"85",
          "arun":'89',
          'aman':'45',
          'akshay':'25'
          }

s_marks.update({'arindati':'97'})

del s_marks['aman']
print(s_marks)

# or 

print(remove_name:=s_marks.pop('arun'))
print(s_marks)
# Out:
# {'anil': '85', 'arun': '89', 'akshay': '25', 'arindati': '97'}
# 89
# {'anil': '85', 'akshay': '25', 'arindati': '97'}

# %%
# 75. Loop through a dictionary and print all keys, then all values, then both together using
# .items() .

cricket_board ={'India':'bcci',
          'England':'ecb',
          'Afghanistan':"acb",
          "South africa":"sca",
          "Bangladesh":'bca'}
print(cricket_board)



for key, value in cricket_board.items():
    print(f"{key}: {value}")
# Out:
# {'India': 'bcci', 'England': 'ecb', 'Afghanistan': 'acb', 'South africa': 'sca', 'Bangladesh': 'bca'}
# India: bcci
# England: ecb
# Afghanistan: acb
# South africa: sca
# Bangladesh: bca

# %%
#  Check if a key exists in a dictionary using in .
if key in cricket_board.keys():
    print(key)
# Out:
# Bangladesh

# %%
# 77. Merge two dictionaries using the | operator (or .update() ).

actors={'telugu':'chiranjivi',
      'kannada':'shivrajkumar',
      'malyalam':'mohanlal',
      'tamil':'rajinikanth'}
print(actors)

films ={"tel":"indra",
        'kan':'om',
        "mal":'premalu',
        "tam":"jailer"}
print(films)

print(mergs:=actors|films)
# Out:
# {'telugu': 'chiranjivi', 'kannada': 'shivrajkumar', 'malyalam': 'mohanlal', 'tamil': 'rajinikanth'}
# {'tel': 'indra', 'kan': 'om', 'mal': 'premalu', 'tam': 'jailer'}

# %%
actors.update(films)
print(actors)
# Out:
# {'telugu': 'chiranjivi', 'kannada': 'shivrajkumar', 'malyalam': 'mohanlal', 'tamil': 'rajinikanth', 'tel': 'indra', 'kan': 'om', 'mal': 'premalu', 'tam': 'jailer'}
