# %%
def add_numbers(*args):
    total = 0
    for number in args:
        total += number
    return total

print(add_numbers(1, 2, 3))        
print(add_numbers(10, 20, 30, 40)) 
print(add_numbers())
# Out:
# 6
# 100
# 0

# %%
# example of kwargs

def labeled_backpack(**kwargs):
    print(kwargs)

labeled_backpack(toy="teddy bear", snack="cookie", drink="juice")
# Out:
# {'toy': 'teddy bear', 'snack': 'cookie', 'drink': 'juice'}

# %%
# Write a function that accepts keyword arguments using **kwargs and prints each
# key-value pair.

def movies(**kwargs):
    return (kwargs)
movies(tamil ="kabali",telugu='Bahubali',kannada ="KGF")
# Out:
# {'tamil': 'kabali', 'telugu': 'Bahubali', 'kannada': 'KGF'}

# %%
# Write a function that returns multiple values (as a tuple) — e.g., min and max of a list.
def number(numbers):  # Renamed parameter to plural for clarity
    minimum = min(numbers)
    maximum = max(numbers)
    return minimum, maximum

# ✅ Correct: Pass a list
print(number([21, 21]))        # Output: (21, 21)
print(number([5, 10, 2, 8]))   # Output: (2, 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 7
#       3     minimum =min(number)
#       4     maximum =max(number)
#       5     return minimum ,maximum
#       6
# ----> 7 print(number(21,21))
#
# TypeError: number() takes 1 positional argument but 2 were given
