# %%
# Section 9: Functions (Q81–92)
# Write a function greet(name) that returns "Hello, <name> !" and call it.

def name():
    print("hello")
name()
# Out:
# hello

# %%
def greet(name):
    return (f"hello, {name}")
message = greet("Alice")
print(message)
# Out:
# hello, Alice

# %%
Write a function to check if a number is prime, and reuse it in a loop to print primes
from 1–50.
# Out:
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
